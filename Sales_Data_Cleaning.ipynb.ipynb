# %%
#Data load


import pandas as pd

df = pd.read_excel("sales_raw_500.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 #Data load
# ----> 4 import pandas as pd
#       6 df = pd.read_excel("sales_raw_500.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:36
#      32 del _hard_dependencies, _dependency, _missing_dependencies
#      34 try:
#      35     # numpy compat
# ---> 36     from pandas.compat import (
#      37         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401,E501
#      38     )
#      39 except ImportError as _err:  # pragma: no cover
#      40     _module = _err.name
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\__init__.py:27
#      25 import pandas.compat.compressors
#      26 from pandas.compat.numpy import is_numpy_dev
# ---> 27 from pandas.compat.pyarrow import (
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Admin\Desktop\Sales Data ETL & Business Intelligence Dashboard
# ['.ipynb_checkpoints', 'Cleaning.ipynb', 'sales_raw_500.xlsx', '~$sales_raw_500.xlsx']

# %%
import pandas as pd

df = pd.read_excel("sales_raw_500.xlsx")

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_excel("sales_raw_500.xlsx")
#       5 df.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:36
#      32 del _hard_dependencies, _dependency, _missing_dependencies
#      34 try:
#      35     # numpy compat
# ---> 36     from pandas.compat import (
#      37         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401,E501
#      38     )
#      39 except ImportError as _err:  # pragma: no cover
#      40     _module = _err.name
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\__init__.py:27
#      25 import pandas.compat.compressors
#      26 from pandas.compat.numpy import is_numpy_dev
# ---> 27 from pandas.compat.pyarrow import (
# ...

# %%
import os

print(os.getcwd())
print([f for f in os.listdir() if "pyarrow" in f.lower()])
# Out:
# C:\Users\Admin\Desktop\Sales Data ETL & Business Intelligence Dashboard
# []

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\python.exe

# %%
print("Kernel restarted successfully")
# Out:
# Kernel restarted successfully

# %%
import pandas as pd

df = pd.read_excel("sales_raw_500.xlsx")

df.head()
# Out:
#    Order_ID Order_Date Customer Region  Product  Sales   Cost
# 0      1001 2023-01-13    Rohit  South   Mobile  23289  19118
# 1      1002 2023-10-07     Aman   West   Laptop   8905   5593
# 2      1003 2023-11-05    Rahul  South  Monitor  59987  39959
# 3      1004 2024-02-19    Rahul  South  Printer  49597  33892
# 4      1005 2024-01-26   Anjali  North   Laptop  54797  34468

# %%
df
# Out:
#      Order_ID Order_Date Customer Region  Product  Sales   Cost
# 0        1001 2023-01-13    Rohit  South   Mobile  23289  19118
# 1        1002 2023-10-07     Aman   West   Laptop   8905   5593
# 2        1003 2023-11-05    Rahul  South  Monitor  59987  39959
# 3        1004 2024-02-19    Rahul  South  Printer  49597  33892
# 4        1005 2024-01-26   Anjali  North   Laptop  54797  34468
# ..        ...        ...      ...    ...      ...    ...    ...
# 515      1389 2024-02-12    Vikas  North   Laptop  17924  12145
# 516      1496 2023-04-24    Kiran  North  Printer  23434  16388
# 517      1031 2023-02-19    Vikas   East  Printer  58883  43579
# 518      1317 2023-07-05     Aman  North   Laptop  76781  66865
# 519      1409 2024-01-16    Pooja  North  Monitor  19969  13586
#
# [520 rows x 7 columns]

# %%
#duplicate remove


df = df.drop_duplicates()

# %%
df
# Out:
#      Order_ID Order_Date Customer Region  Product  Sales   Cost
# 0        1001 2023-01-13    Rohit  South   Mobile  23289  19118
# 1        1002 2023-10-07     Aman   West   Laptop   8905   5593
# 2        1003 2023-11-05    Rahul  South  Monitor  59987  39959
# 3        1004 2024-02-19    Rahul  South  Printer  49597  33892
# 4        1005 2024-01-26   Anjali  North   Laptop  54797  34468
# ..        ...        ...      ...    ...      ...    ...    ...
# 495      1496 2023-04-24    Kiran  North  Printer  23434  16388
# 496      1497 2023-06-27   Anjali  South   Laptop  49007  35970
# 497      1498 2023-05-08     Aman   East   Tablet  19160  15636
# 498      1499        NaT    Pooja   West   Mobile  59266  44326
# 499      1500 2023-10-07    Vikas  North  Printer  34567  22426
#
# [500 rows x 7 columns]

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15200\356155431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    500 non-null    int64
#  1   Order_Date  482 non-null    datetime64[ns]
#  2   Customer    500 non-null    object
#  3   Region      500 non-null    object
#  4   Product     500 non-null    object
#  5   Sales       500 non-null    int64
#  6   Cost        500 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 31.2+ KB

# %%
df = df.dropna(subset=['Order_Date'])

# %%
df
# Out:
#      Order_ID Order_Date Customer Region  Product  Sales   Cost
# 0        1001 2023-01-13    Rohit  South   Mobile  23289  19118
# 1        1002 2023-10-07     Aman   West   Laptop   8905   5593
# 2        1003 2023-11-05    Rahul  South  Monitor  59987  39959
# 3        1004 2024-02-19    Rahul  South  Printer  49597  33892
# 4        1005 2024-01-26   Anjali  North   Laptop  54797  34468
# ..        ...        ...      ...    ...      ...    ...    ...
# 494      1495 2023-10-18    Rahul  South  Monitor  46709  40931
# 495      1496 2023-04-24    Kiran  North  Printer  23434  16388
# 496      1497 2023-06-27   Anjali  South   Laptop  49007  35970
# 497      1498 2023-05-08     Aman   East   Tablet  19160  15636
# 499      1500 2023-10-07    Vikas  North  Printer  34567  22426
#
# [482 rows x 7 columns]

# %%
df['Profit'] = df['Sales']-df['Cost']
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15200\3679951826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit'] = df['Sales']-df['Cost']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15200\3679951826.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Order_Date'].dt.year
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15200\3679951826.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df = df.dropna(subset=['Order_Date'])

df = df.copy()

df['Profit'] = df['Sales'] - df['Cost']
df['Year'] = df['Order_Date'].dt.year
df['Month'] = df['Order_Date'].dt.month

# %%
df
# Out:
#      Order_ID Order_Date Customer Region  Product  Sales   Cost  Profit  Year  \
# 0        1001 2023-01-13    Rohit  South   Mobile  23289  19118    4171  2023
# 1        1002 2023-10-07     Aman   West   Laptop   8905   5593    3312  2023
# 2        1003 2023-11-05    Rahul  South  Monitor  59987  39959   20028  2023
# 3        1004 2024-02-19    Rahul  South  Printer  49597  33892   15705  2024
# 4        1005 2024-01-26   Anjali  North   Laptop  54797  34468   20329  2024
# ..        ...        ...      ...    ...      ...    ...    ...     ...   ...
# 494      1495 2023-10-18    Rahul  South  Monitor  46709  40931    5778  2023
# 495      1496 2023-04-24    Kiran  North  Printer  23434  16388    7046  2023
# 496      1497 2023-06-27   Anjali  South   Laptop  49007  35970   13037  2023
# 497      1498 2023-05-08     Aman   East   Tablet  19160  15636    3524  2023
# 499      1500 2023-10-07    Vikas  North  Printer  34567  22426   12141  2023
#
#      Month
# 0        1
# ...

# %%
df.to_csv('sales_cleaned.csv',index = False)

# %%
#data python + Excel + SQL

# %%
import pandas as pd
fromsqlalchemy import create_engine

# %%
pd.read_csv('sales_cleaned.csv')

# %%
df
# Out:
#      Order_ID Order_Date Customer Region  Product  Sales   Cost  Profit  Year  \
# 0        1001 2023-01-13    Rohit  South   Mobile  23289  19118    4171  2023
# 1        1002 2023-10-07     Aman   West   Laptop   8905   5593    3312  2023
# 2        1003 2023-11-05    Rahul  South  Monitor  59987  39959   20028  2023
# 3        1004 2024-02-19    Rahul  South  Printer  49597  33892   15705  2024
# 4        1005 2024-01-26   Anjali  North   Laptop  54797  34468   20329  2024
# ..        ...        ...      ...    ...      ...    ...    ...     ...   ...
# 494      1495 2023-10-18    Rahul  South  Monitor  46709  40931    5778  2023
# 495      1496 2023-04-24    Kiran  North  Printer  23434  16388    7046  2023
# 496      1497 2023-06-27   Anjali  South   Laptop  49007  35970   13037  2023
# 497      1498 2023-05-08     Aman   East   Tablet  19160  15636    3524  2023
# 499      1500 2023-10-07    Vikas  North  Printer  34567  22426   12141  2023
#
#      Month
# 0        1
# ...

# %%
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/salesdb')

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:MyPassword123@localhost:5432/salesdb"
)

# %%
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 engine.connect()
#
# NameError: name 'engine' is not defined

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:MyPassword123@localhost:5432/salesdb"
)

# %%
engine.connect()

# %%
df.head()
# Out:
#    Order_ID Order_Date Customer Region  Product  Sales   Cost  Profit  Year  \
# 0      1001 2023-01-13    Rohit  South   Mobile  23289  19118    4171  2023
# 1      1002 2023-10-07     Aman   West   Laptop   8905   5593    3312  2023
# 2      1003 2023-11-05    Rahul  South  Monitor  59987  39959   20028  2023
# 3      1004 2024-02-19    Rahul  South  Printer  49597  33892   15705  2024
# 4      1005 2024-01-26   Anjali  North   Laptop  54797  34468   20329  2024
#
#    Month
# 0      1
# 1     10
# 2     11
# 3      2
# 4      1

# %%
df.to_sql(
    "sales",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 482

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:Diksha2573@localhost:5432/salesdb"
)

# %%
engine.connect()

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5;", engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_sql("SELECT * FROM sales LIMIT 5;", engine)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/salesdb)

# %%
df['Order_Date'] = pd.to_datetime(['Order_Date']), errors='coerce')
# Out:
#   Cell In[9], line 1
#     df['Order_Date'] = pd.to_datetime(['Order_Date']), errors='coerce')
#                                                                       ^
# SyntaxError: unmatched ')'

# %%
import pandas as pd

# %%
pd.read_sql("SELECT * FROM sales LIMIT 5;", engine)
# Out:
#    Order_ID Order_Date Customer Region  Product  Sales   Cost  Profit  Year  \
# 0      1001 2023-01-13    Rohit  South   Mobile  23289  19118    4171  2023
# 1      1002 2023-10-07     Aman   West   Laptop   8905   5593    3312  2023
# 2      1003 2023-11-05    Rahul  South  Monitor  59987  39959   20028  2023
# 3      1004 2024-02-19    Rahul  South  Printer  49597  33892   15705  2024
# 4      1005 2024-01-26   Anjali  North   Laptop  54797  34468   20329  2024
#
#    Month
# 0      1
# 1     10
# 2     11
# 3      2
# 4      1

# %%
df.to_sql(
    "sales",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.to_sql(
#       2     "sales",
#       3     engine,
#       4     if_exists="replace",
#       5     index=False
#       6 )
#
# NameError: name 'df' is not defined
